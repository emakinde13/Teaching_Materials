# %% [markdown]
# ### Perceptron

# %% [markdown]
# In this notebook, you will create a basic perceptron! A perceptron is a basic neural network which uses one node that compares the weighted sum of inputs to a bias or threshold term. In this notebook, you will define two functions: a function that takes in a vector of inputs and weights of the same dimensionality as well as a bias term, b, and returns z, the sum of the weighted inputs + the bias. The second function will be your activation function for the perceptron, which should take in the parameter, z, and returns a boolean.
#
# Remember the following formula for z: $$z = \vec{w}^T \vec{x} + b$$
# And for your activation:
# $$a =f(z) =
# \begin{cases}
# 1 & z>0 \\
# 0 & z\le 0
# \end{cases}$$

# %% [markdown]
# #### Import Statements

# %%
import ____ as __ # We'll be working with numbers
import __________ as __ # We'll be plotting!

# %% [markdown]
# #### Weight Function

# %%
def perceptron():
    # Your code goes here
    return z

# %% [markdown]
# #### Activation Function

# %%
def activation():
    # Your code goes here
    return a

# %% [markdown]
# #### Test
# Test your functions on the following data and see what you get!

# %%
# Bias/Threshold
b = -5

# Test 1
x1 =  np.array([-3, -5, 4]) # What value of the 2nd element makes this positive? Try a few integers.
w1 =  np.array([1, 2, 3])

# Test 2
x2 =  np.random.normal(0,5,10)
w2 =  np.random.randint(-3,3,10)

# %% [markdown]
# Simulate the perceptron 1000 times and store the outputs of the activation function in an array. Then plot the histogram and observe the distribution of 1s and 0s from your perceptrons decision. How can you explain the skew in the distribution between 1s and 0s?

# %%
# Run your perceptron 1000 times!
# Your code here





# Plot a histogram!
